# %%
import os
from os import listdir
newfilename=[]
filepath = input("Enter File Path:")
print(filepath)
# Out:
# Enter File Path:C:\Users\bongb\OneDrive - Vircon Limited\Project\Revit\Training Note\3ds Max Training\Lynda - 3ds Max Tips and Tricks
# C:\Users\bongb\OneDrive - Vircon Limited\Project\Revit\Training Note\3ds Max Training\Lynda - 3ds Max Tips and Tricks

# %%
filename=listdir(filepath)
#inputvalue = input("input date to be replaced")
#replacevalue = input("input the new date")
print(filename)
# Out:
# ['1 Exercise files.mp4', '1 Exercise files.srt', '1 Modeling a floor plan from a 2D drafting document.mp4', '1 Modeling a floor plan from a 2D drafting document.srt', '1 Parametric soft transforms with Affect Region.mp4', '1 Parametric soft transforms with Affect Region.srt', '1 Welcome.mp4', '1 Welcome.srt', '1 What to know.mp4', '1 What to know.srt', '10 Real-time animation with the Motion Capture utility.mp4', '10 Real-time animation with the Motion Capture utility.srt', '100 Editing animation curves with the Region Keys tool.mp4', '101 Combining data channels of Fluids.mp4', '101 Combining data channels of Fluids.srt', '102 Shading per object with OSL Random by Index.mp4', '102 Shading per object with OSL Random by Index.srt', '103 Layering materials of Fluids.mp4', '103 Layering materials of Fluids.srt', '104 Render particles as Arnold primitives.mp4', '104 Render particles as Arnold primitives.srt', '105 Render PFlow particles with Arnold Shape.mp4', '105 Render PFlow particles with Arnold Shape.srt', '106 Remapping colors with Arnold Ramp RGB.mp4', '106 Remapping colors with Arnold Ramp RGB.srt', '107 Rendering contours with Arnold Toon.mp4', '107 Rendering contours with Arnold Toon.srt', '108 Mapping Arnold Toon base color.mp4', '108 Mapping Arnold Toon base color.srt', '109 Controlling preview quality.mp4', '109 Controlling preview quality.srt', "11 Stylized rendering with Scanline Ink 'n Paint.mp4", "11 Stylized rendering with Scanline Ink 'n Paint.srt", '110 Adding information overlays to a preview with MAXScript.mp4', '110 Adding information overlays to a preview with MAXScript.srt', '111 Modeling with the updated Chamfer modifier.mp4', '111 Modeling with the updated Chamfer modifier.srt', '112 Applying a chamfer using edge weight and depth.mp4', '112 Applying a chamfer using edge weight and depth.srt', '113 Baking a map to a mesh with Assign Vertex Color.mp4', '113 Baking a map to a mesh with Assign Vertex Color.srt', '114 Generating cavity and occlusion maps with Render Surface Map.mp4', '114 Generating cavity and occlusion maps with Render Surface Map.srt', '115 Baking multiple vertex color channels with VertexPaint.mp4', '115 Baking multiple vertex color channels with VertexPaint.srt', '116 Compositing vertex color in a shading network.mp4', '116 Compositing vertex color in a shading network.srt', '117 Optimizing geometry with the MultiRes modifier.mp4', '117 Optimizing geometry with the MultiRes modifier.srt', '118 Improving viewport performance with the Substitute modifier.mp4', '118 Improving viewport performance with the Substitute modifier.srt', '119 Constructing a lighting assembly.mp4', '119 Constructing a lighting assembly.srt', '12 Getting started with the Max Creation Graph.mp4', '12 Getting started with the Max Creation Graph.srt', '120 Wiring parameters in a lighting assembly.mp4', '120 Wiring parameters in a lighting assembly.srt', '121 Measuring with tape helper, the Measure Distance tool, and the Measure utility.mp4', '121 Measuring with tape helper, the Measure Distance tool, and the Measure utility.srt', '122 Display panel tips and tricks.mp4', '122 Display panel tips and tricks.srt', '123 Quickly adjusting transforms and pivot point with the Transform Toolbox.mp4', '123 Quickly adjusting transforms and pivot point with the Transform Toolbox.srt', '124 Stacking objects with Select and Place.mp4', '124 Stacking objects with Select and Place.srt', '125 Managing objects and sub-objects with selection sets.mp4', '125 Managing objects and sub-objects with selection sets.srt', '126 Referencing scenes with containers.mp4', '126 Referencing scenes with containers.srt', '127 Changing inherited container content with Edit in Place.mp4', '127 Changing inherited container content with Edit in Place.srt', '128 Locking and unlocking container parameters.mp4', '128 Locking and unlocking container parameters.srt', '129 Editing unlocked container parameters.mp4', '129 Editing unlocked container parameters.srt', ...

# %%
newfilename=[]
for i in filename:
    
    #newfilename.append(i.replace(inputvalue, replacevalue))
    ##y=i.replace(r"[","")
    ##y1=y.replace(r"]","")
    #newfilename.append(i)
    #print(newfilename)
    
    y=i.split(" ")
    y[0]=format(int(y[0]),'03')
    i=' '.join(y)
    newfilename.append(i)
# Out:
# 001
# 001
# 001
# 001
# 001
# 001
# 001
# 001
# 001
# 001
# 010
# 010
# 100
# 101
# 101
# 102
# 102
# 103
# 103
# 104
# 104
# 105
# 105
# 106
# 106
# 107
# 107
# 108
# 108
# 109
# 109
# 011
# 011
# 110
# 110
# 111
# 111
# 112
# 112
# 113
# 113
# 114
# 114
# 115
# 115
# 116
# 116
# 117
# 117
# 118
# 118
# 119
# 119
# 012
# 012
# 120
# 120
# 121
# 121
# 122
# 122
# 123
# 123
# 124
# 124
# 125
# 125
# 126
# 126
# 127
# 127
# 128
# 128
# 129
# 129
# 013
# 013
# 130
# 130
# 131
# 131
# 132
# 132
# 133
# 133
# 134
# 134
# 135
# 135
# 136
# 136
# 137
# 137
# 138
# 138
# 139
# 139
# 014
# 014
# 140
# 140
# 141
# 141
# 142
# 142
# 143
# 143
# 144
# 144
# 145
# 145
# 146
# 146
# 147
# 147
# 148
# 148
# 149
# 149
# 015
# 015
# 150
# 150
# 151
# 151
# 152
# 152
# 153
# 153
# 154
# 154
# 155
# 155
# 156
# 156
# 157
# 157
# 158
# 158
# 159
# 159
# 016
# 016
# 160
# 160
# 161
# 161
# 162
# 162
# 163
# 163
# 164
# 164
# 165
# 165
# 166
# 166
# 167
# 167
# 168
# 168
# 017
# 017
# 018
# 018
# 019
# 019
# 002
# 002
# 020
# 020
# 021
# 021
# 022
# 022
# 023
# 023
# 024
# 024
# 025
# 025
# 026
# 026
# 027
# 027
# 028
# 028
# 029
# 029
# 003
# 003
# 030
# 030
# 031
# 031
# 032
# 032
# 033
# 033
# 034
# 034
# 035
# 035
# 036
# 036
# 037
# 037
# 038
# 038
# 039
# 039
# 004
# 004
# 040
# 040
# 041
# 041
# 042
# 042
# 043
# 043
# 044
# 044
# 045
# 045
# 046
# 046
# 047
# 047
# 048
# 048
# 049
# 049
# 005
# 005
# 050
# 050
# 051
# 051
# 052
# 052
# 053
# 053
# 054
# 054
# 055
# 055
# 056
# 056
# 057
# 057
# 058
# 058
# 059
# 059
# 006
# 006
# 060
# 060
# 061
# 061
# 062
# 062
# 063
# 063
# 064
# 064
# 065
# 065
# 066
# 066
# 067
# 067
# 068
# 068
# 069
# 069
# 007
# 007
# 070
# 070
# 071
# 071
# 072
# 072
# 073
# 073
# 074
# 074
# 075
# 075
# 076
# 076
# 077
# 077
# 078
# 078
# 079
# 079
# 008
# 008
# 080
# 080
# 081
# 081
# 082
# 082
# 083
# 083
# 084
# 084
# 085
# 085
# 086
# 086
# 087
# 087
# 088
# 088
# 089
# 089
# 009
# 009
# 090
# 090
# 091
# 091
# 092
# 092
# 093
# 093
# 094
# 094
# 095
# 095
# 096
# 096
# 097
# 097
# 098
# 098
# 099
# 099

# %%
for item in range(len(filename)):
    os.rename(filepath+"\\"+filename[item],filepath+"\\"+newfilename[item])
